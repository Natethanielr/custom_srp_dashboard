# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('dailyCost7_14_2025_to_8_4_2025.csv')
df['Usage date'] = pd.to_datetime(df['Usage date'])
df['Total cost'] = df['Total cost'].replace({'\\$': '', ',': ''}, regex=True).astype(float)
df['Day of week'] = df['Usage date'].dt.day_name()
print(df.dtypes)
df.head()
# Out:
# Meter read date                 object
# Usage date              datetime64[ns]
# Total cost                     float64
# High temperature (F)           float64
# Low temperature (F)            float64
# Day of week                     object
# dtype: object
#   Meter read date Usage date  Total cost  High temperature (F)  \
# 0       7/15/2025 2025-07-14        6.81                 105.0
# 1       7/16/2025 2025-07-15        4.42                 105.0
# 2       7/17/2025 2025-07-16        3.23                  95.0
# 3       7/18/2025 2025-07-17        3.53                 100.0
# 4       7/19/2025 2025-07-18        5.17                 106.0
#
#    Low temperature (F) Day of week
# 0                 87.0      Monday
# 1                 86.0     Tuesday
# 2                 82.0   Wednesday
# 3                 80.0    Thursday
# 4                 86.0      Friday

# %%
colors = ['red' if day in ['Saturday', 'Sunday'] else 'blue' for day in df['Day of week']]
fig, ax = plt.subplots(figsize = (10,5))
ax.bar(df['Usage date'], df['Total cost'], edgecolor = colors, label = 'Total Cost')
#ax.plot(df['Usage date'], df['Total cost'],'k')
ax1 = ax.twinx()
ax1.plot(df['Usage date'], df['High temperature (F)'], 'k', ls = 'dotted', label = 'High temperature') 
ax.set_xlabel('Usage date')
ax.set_ylabel('Cost $')
ax1.set_ylabel('Temperature')
ax.legend()
ax1.legend()

# %%
stat = df['Total cost'][:-1].agg(['mean', 'max', 'min', 'std'])
print(stat)
type(stat)
# Out:
# mean    5.047273
# max     6.810000
# min     3.230000
# std     1.028305
# Name: Total cost, dtype: float64
# pandas.core.series.Series

# %%
weekend_costs = df[df["Day of week"].isin(["Saturday", "Sunday"])]["Total cost"]
print(weekend_costs)
# Out:
# 5     5.62
# 6     5.02
# 12    3.53
# 13    5.32
# 19    6.66
# 20    4.72
# Name: Total cost, dtype: float64
